# %%
import pandas as pd
import json

# %%
was_df = pd.read_csv("helpers/was_database.csv")
was_df.head()
# Out:
#    Unnamed: 0      Publisher                                       Title  \
# 0         NaN  Was editorial              Si vas a soñar hazlo en grande
# 1         NaN  Was editorial                         Tu calabaza gigante
# 2         NaN  Was editorial                                Sinergéticos
# 3         NaN  Was editorial  Conectando con la energía de la abundancia
# 4         NaN  Was editorial       Cómo escribir un libro extraordinario
#
#                                            Author(s)           ISBN Unnamed: 5
# 0                                Juan Carlos Barrios  9786072927285        NaN
# 1                                Juan Carlos Barrios  9786075941714        NaN
# 2                                     Jorge Serratos  9786075962078        NaN
# 3                                  Alex Gomez Medina  9786079948580        NaN
# 4  Rebeca González, Juan Carlos Barrios, Spencer ...  9786079982072        NaN

# %%
was_df.columns
was_df = was_df.drop(columns=['Unnamed: 0', 'Publisher', 'Unnamed: 5'])
was_df.head()
# Out:
#                                         Title  \
# 0              Si vas a soñar hazlo en grande
# 1                         Tu calabaza gigante
# 2                                Sinergéticos
# 3  Conectando con la energía de la abundancia
# 4       Cómo escribir un libro extraordinario
#
#                                            Author(s)           ISBN
# 0                                Juan Carlos Barrios  9786072927285
# 1                                Juan Carlos Barrios  9786075941714
# 2                                     Jorge Serratos  9786075962078
# 3                                  Alex Gomez Medina  9786079948580
# 4  Rebeca González, Juan Carlos Barrios, Spencer ...  9786079982072

# %%
authors = []
for x in was_df['Author(s)']:
    x_string = str(x)
    split = x_string.split(',')
    for y in split:
        y_split = y.split(' ')

        for z in y_split:
            if z == "":
                y_split.remove(z)
            z = z.capitalize()
        y_capitalized = " ".join(y_split)
        print(y_capitalized)
        if y_capitalized in authors or y == "nan":
            continue
        authors.append(y_capitalized)
authors
# Out:
# Juan Carlos Barrios
# Juan Carlos Barrios
# Jorge Serratos
# Alex Gomez Medina
# Rebeca González
# Juan Carlos Barrios
# Spencer Hoffmann
# Alex Palombo
# Alex Palombo
# Yoel Sardiñas
# Yoel Sardiñas
# Erika Torres
# Elisa Ramírez
# Alex Vazquez
# Alex Vazquez
# Spencer Hoffmann
# Adriana Vega
# Jenny Linares
# Elizabeth Reséndiz
# Rocío Jimenez Nolasco
# Diana Martínez Partida
# Francisco Escobar
# Mónica Viviana Arias Arcila
# Daisy Rosales
# Nara Trejo
# Sofía Muñiz
# Irma Rocha
# Nancy Valiente
# David Hernández
# Ana Paola Ramos Uriarte y Jaime Guzmán Fontanot
# Jeanette Candiani
# Graciela Pedro
# Oscar Ramírez
# Chef Coco González
# Pasta dura Coco
# Nicolás Robles
# Jesús Rivas y Carolina Candedo
# José Fernando Montes Arias
# Jesus Alberto Santacruz
# Juan Manuel Morales
# José Ardón
# Angélica Lighten
# Shariteé Salgado
# Was editorial
# Marina Rodríguez
# Mark Achar
# Doris Michan
# Josue Mejia
# Gumaro Bracho
# Patty González
# Lisayly Hurtado Romero
# Paco Hernández
# Olas de Luz
# Compilación de cuentos
# Denisse Rendón
# Sandra Ballesteros
# Esther Delgado
# Sergio León Hernández
# Javier y Sahid Reyes
# Mihail Millet
# Jaime Lokier
# Arturo Jiménez
# Verónika Santos
# María Felix
# Sánchez
# Luis Rhino
# Isabel Vargas
# César Moysén.
# Verónika Santos
# Lucy Santos
# Luz García
# Lili Alba
# Paty anaya.
# Verónika Satos
# José Luis Monsalvo
# Flor Castillo
# Bruno Trinidad
# Rosalba Rodarte
# Mirna Guzmán.
# Verónika Santos
# Simon Cohen
# Coral Mujaes
# Nayo Escobar
# Raciel Trejo
# Lupita Arias
# Eduardo Rodríguez
# Patty Álvarez padilla
# Itala Ureta
# Diana Pau González.
# Randy Gage
# Lulu Frompr
# Luisa Rios
# Dr. Moño.
# Emily Chavez Daumas
# Ricardo Calderón de la Barca
# Ana Michell
# Sergio Nava
# Enrique Moreno
# Esmeralda Salas.
# Jaime Lokier
# Verónica del Castillo
# Simon Cohen
# Margarita Miranda Correa
# Luiggi Lavin
# Milly Moreno
# Diana Pau González.
# Coral Mujaes
# Yuri Mendoza
# Alberto
# Flor
# Alex Palombo
# Lavín11:11
# Coral Mujaes
# Jhony
# Jhony
# Jhony
# Jhony
# Jorge Rosas
# Serratos
# Emily Chavez Daumas
# Andie Lozano
# Gaby Jaime
# David de Alba
# Elizabeth casillas
# Israel Flores
# Rodrigo del Val
# Jessica Garza
# Ceciia Galindo
# Lorena Arelluk
# Karla Zorola
# Estrella
# Alejandro Saracho
# Alejandro Saracho
# Alejandro Saracho
# Isabella Cisneros
# Serratos
# Juan y Rebe
# Lili Jaime
# Patty Verdugo
# Ana Lugo
# Ana Munguía
# Leonor Verdugo
# Minerva martinez
# Cristian Chablé
# Marcela chavez
# Leticia rodriguez
# Anna ferro
# Pilar rosas
# Patricia moreno
# Omar perez
# Yhashua Sámano
# Jacky Moguel
# Yoel
# Raciel
# Rosmy Quiroz
# Oscar lomeli
# Oscar lopez
# Yuri Mendoza
# Rodrigo hellfer
# Tato
# Tato
# Tato
# Tato
# Marisol
# nan
# nan
# Caro Cruz
# José Manuel de León Gutierrez
# Emily Chavez Daumas
# ['Juan Carlos Barrios',
#  'Jorge Serratos',
#  'Alex Gomez Medina',
#  'Rebeca González',
#  'Spencer Hoffmann',
#  'Alex Palombo',
#  'Yoel Sardiñas',
#  'Erika Torres',
#  'Elisa Ramírez',
#  'Alex Vazquez',
#  'Adriana Vega',
#  'Jenny Linares',
#  'Elizabeth Reséndiz',
#  'Rocío Jimenez Nolasco',
#  'Diana Martínez Partida',
#  'Francisco Escobar',
#  'Mónica Viviana Arias Arcila',
#  'Daisy Rosales',
#  'Nara Trejo',
#  'Sofía Muñiz',
#  'Irma Rocha',
#  'Nancy Valiente',
#  'David Hernández',
#  'Ana Paola Ramos Uriarte y Jaime Guzmán Fontanot',
#  'Jeanette Candiani',
#  'Graciela Pedro',
#  'Oscar Ramírez',
#  'Chef Coco González',
#  'Pasta dura Coco',
#  'Nicolás Robles',
#  'Jesús Rivas y Carolina Candedo',
#  'José Fernando Montes Arias',
#  'Jesus Alberto Santacruz',
#  'Juan Manuel Morales',
#  'José Ardón',
#  'Angélica Lighten',
#  'Shariteé Salgado',
#  'Was editorial',
#  'Marina Rodríguez',
#  'Mark Achar',
#  'Doris Michan',
#  'Josue Mejia',
#  'Gumaro Bracho',
#  'Patty González',
#  'Lisayly Hurtado Romero',
#  'Paco Hernández',
#  'Olas de Luz',
#  'Compilación de cuentos',
#  'Denisse Rendón',
#  'Sandra Ballesteros',
#  'Esther Delgado',
#  'Sergio León Hernández',
#  'Javier y Sahid Reyes',
#  'Mihail Millet',
#  'Jaime Lokier',
#  'Arturo Jiménez',
#  'Verónika Santos',
#  'María Felix',
#  'Sánchez',
#  'Luis Rhino',
#  'Isabel Vargas',
#  'César Moysén.',
#  'Lucy Santos',
#  'Luz García',
#  'Lili Alba',
#  'Paty anaya.',
#  'Verónika Satos',
#  'José Luis Monsalvo',
#  'Flor Castillo',
#  'Bruno Trinidad',
#  'Rosalba Rodarte',
#  'Mirna Guzmán.',
#  'Simon Cohen',
#  'Coral Mujaes',
#  'Nayo Escobar',
#  'Raciel Trejo',
#  'Lupita Arias',
#  'Eduardo Rodríguez',
#  'Patty Álvarez padilla',
#  'Itala Ureta',
#  'Diana Pau González.',
#  'Randy Gage',
#  'Lulu Frompr',
#  'Luisa Rios',
#  'Dr. Moño.',
#  'Emily Chavez Daumas',
#  'Ricardo Calderón de la Barca',
#  'Ana Michell',
#  'Sergio Nava',
#  'Enrique Moreno',
#  'Esmeralda Salas.',
#  'Verónica del Castillo',
#  'Margarita Miranda Correa',
#  'Luiggi Lavin',
#  'Milly Moreno',
#  'Yuri Mendoza',
#  'Alberto',
#  'Flor',
#  'Lavín11:11',
#  'Jhony',
#  'Jorge Rosas',
#  'Serratos',
#  'Andie Lozano',
#  'Gaby Jaime',
#  'David de Alba',
#  'Elizabeth casillas',
#  'Israel Flores',
#  'Rodrigo del Val',
#  'Jessica Garza',
#  'Ceciia Galindo',
#  'Lorena Arelluk',
#  'Karla Zorola',
#  'Estrella',
#  'Alejandro Saracho',
#  'Isabella Cisneros',
#  'Juan y Rebe',
#  'Lili Jaime',
#  'Patty Verdugo',
#  'Ana Lugo',
#  'Ana Munguía',
#  'Leonor Verdugo',
#  'Minerva martinez',
#  'Cristian Chablé',
#  'Marcela chavez',
#  'Leticia rodriguez',
#  'Anna ferro',
#  'Pilar rosas',
#  'Patricia moreno',
#  'Omar perez',
#  'Yhashua Sámano',
#  'Jacky Moguel',
#  'Yoel',
#  'Raciel',
#  'Rosmy Quiroz',
#  'Oscar lomeli',
#  'Oscar lopez',
#  'Rodrigo hellfer',
#  'Tato',
#  'Marisol',
#  'Caro Cruz',
#  'José Manuel de León Gutierrez']

# %%
authors2 = []
for author in authors:
    split = author.split(" y ")
    for x in split:
        if x in authors2:
            continue
        authors2.append(x)
authors2
# Out:
# ['Juan Carlos Barrios',
#  'Jorge Serratos',
#  'Alex Gomez Medina',
#  'Rebeca González',
#  'Spencer Hoffmann',
#  'Alex Palombo',
#  'Yoel Sardiñas',
#  'Erika Torres',
#  'Elisa Ramírez',
#  'Alex Vazquez',
#  'Adriana Vega',
#  'Jenny Linares',
#  'Elizabeth Reséndiz',
#  'Rocío Jimenez Nolasco',
#  'Diana Martínez Partida',
#  'Francisco Escobar',
#  'Mónica Viviana Arias Arcila',
#  'Daisy Rosales',
#  'Nara Trejo',
#  'Sofía Muñiz',
#  'Irma Rocha',
#  'Nancy Valiente',
#  'David Hernández',
#  'Ana Paola Ramos Uriarte',
#  'Jaime Guzmán Fontanot',
#  'Jeanette Candiani',
#  'Graciela Pedro',
#  'Oscar Ramírez',
#  'Chef Coco González',
#  'Pasta dura Coco',
#  'Nicolás Robles',
#  'Jesús Rivas',
#  'Carolina Candedo',
#  'José Fernando Montes Arias',
#  'Jesus Alberto Santacruz',
#  'Juan Manuel Morales',
#  'José Ardón',
#  'Angélica Lighten',
#  'Shariteé Salgado',
#  'Was editorial',
#  'Marina Rodríguez',
#  'Mark Achar',
#  'Doris Michan',
#  'Josue Mejia',
#  'Gumaro Bracho',
#  'Patty González',
#  'Lisayly Hurtado Romero',
#  'Paco Hernández',
#  'Olas de Luz',
#  'Compilación de cuentos',
#  'Denisse Rendón',
#  'Sandra Ballesteros',
#  'Esther Delgado',
#  'Sergio León Hernández',
#  'Javier',
#  'Sahid Reyes',
#  'Mihail Millet',
#  'Jaime Lokier',
#  'Arturo Jiménez',
#  'Verónika Santos',
#  'María Felix',
#  'Sánchez',
#  'Luis Rhino',
#  'Isabel Vargas',
#  'César Moysén.',
#  'Lucy Santos',
#  'Luz García',
#  'Lili Alba',
#  'Paty anaya.',
#  'Verónika Satos',
#  'José Luis Monsalvo',
#  'Flor Castillo',
#  'Bruno Trinidad',
#  'Rosalba Rodarte',
#  'Mirna Guzmán.',
#  'Simon Cohen',
#  'Coral Mujaes',
#  'Nayo Escobar',
#  'Raciel Trejo',
#  'Lupita Arias',
#  'Eduardo Rodríguez',
#  'Patty Álvarez padilla',
#  'Itala Ureta',
#  'Diana Pau González.',
#  'Randy Gage',
#  'Lulu Frompr',
#  'Luisa Rios',
#  'Dr. Moño.',
#  'Emily Chavez Daumas',
#  'Ricardo Calderón de la Barca',
#  'Ana Michell',
#  'Sergio Nava',
#  'Enrique Moreno',
#  'Esmeralda Salas.',
#  'Verónica del Castillo',
#  'Margarita Miranda Correa',
#  'Luiggi Lavin',
#  'Milly Moreno',
#  'Yuri Mendoza',
#  'Alberto',
#  'Flor',
#  'Lavín11:11',
#  'Jhony',
#  'Jorge Rosas',
#  'Serratos',
#  'Andie Lozano',
#  'Gaby Jaime',
#  'David de Alba',
#  'Elizabeth casillas',
#  'Israel Flores',
#  'Rodrigo del Val',
#  'Jessica Garza',
#  'Ceciia Galindo',
#  'Lorena Arelluk',
#  'Karla Zorola',
#  'Estrella',
#  'Alejandro Saracho',
#  'Isabella Cisneros',
#  'Juan',
#  'Rebe',
#  'Lili Jaime',
#  'Patty Verdugo',
#  'Ana Lugo',
#  'Ana Munguía',
#  'Leonor Verdugo',
#  'Minerva martinez',
#  'Cristian Chablé',
#  'Marcela chavez',
#  'Leticia rodriguez',
#  'Anna ferro',
#  'Pilar rosas',
#  'Patricia moreno',
#  'Omar perez',
#  'Yhashua Sámano',
#  'Jacky Moguel',
#  'Yoel',
#  'Raciel',
#  'Rosmy Quiroz',
#  'Oscar lomeli',
#  'Oscar lopez',
#  'Rodrigo hellfer',
#  'Tato',
#  'Marisol',
#  'Caro Cruz',
#  'José Manuel de León Gutierrez']

# %%
authors_capped = []
for author in authors2:
    split = author.split(' ')
    capped=[]
    for x in split:
        capped.append(x.capitalize())
    capped_author = " ".join(capped)
    if capped_author in authors_capped:
        continue
    authors_capped.append(capped_author)
authors_capped
# Out:
# ['Juan Carlos Barrios',
#  'Jorge Serratos',
#  'Alex Gomez Medina',
#  'Rebeca González',
#  'Spencer Hoffmann',
#  'Alex Palombo',
#  'Yoel Sardiñas',
#  'Erika Torres',
#  'Elisa Ramírez',
#  'Alex Vazquez',
#  'Adriana Vega',
#  'Jenny Linares',
#  'Elizabeth Reséndiz',
#  'Rocío Jimenez Nolasco',
#  'Diana Martínez Partida',
#  'Francisco Escobar',
#  'Mónica Viviana Arias Arcila',
#  'Daisy Rosales',
#  'Nara Trejo',
#  'Sofía Muñiz',
#  'Irma Rocha',
#  'Nancy Valiente',
#  'David Hernández',
#  'Ana Paola Ramos Uriarte',
#  'Jaime Guzmán Fontanot',
#  'Jeanette Candiani',
#  'Graciela Pedro',
#  'Oscar Ramírez',
#  'Chef Coco González',
#  'Pasta Dura Coco',
#  'Nicolás Robles',
#  'Jesús Rivas',
#  'Carolina Candedo',
#  'José Fernando Montes Arias',
#  'Jesus Alberto Santacruz',
#  'Juan Manuel Morales',
#  'José Ardón',
#  'Angélica Lighten',
#  'Shariteé Salgado',
#  'Was Editorial',
#  'Marina Rodríguez',
#  'Mark Achar',
#  'Doris Michan',
#  'Josue Mejia',
#  'Gumaro Bracho',
#  'Patty González',
#  'Lisayly Hurtado Romero',
#  'Paco Hernández',
#  'Olas De Luz',
#  'Compilación De Cuentos',
#  'Denisse Rendón',
#  'Sandra Ballesteros',
#  'Esther Delgado',
#  'Sergio León Hernández',
#  'Javier',
#  'Sahid Reyes',
#  'Mihail Millet',
#  'Jaime Lokier',
#  'Arturo Jiménez',
#  'Verónika Santos',
#  'María Felix',
#  'Sánchez',
#  'Luis Rhino',
#  'Isabel Vargas',
#  'César Moysén.',
#  'Lucy Santos',
#  'Luz García',
#  'Lili Alba',
#  'Paty Anaya.',
#  'Verónika Satos',
#  'José Luis Monsalvo',
#  'Flor Castillo',
#  'Bruno Trinidad',
#  'Rosalba Rodarte',
#  'Mirna Guzmán.',
#  'Simon Cohen',
#  'Coral Mujaes',
#  'Nayo Escobar',
#  'Raciel Trejo',
#  'Lupita Arias',
#  'Eduardo Rodríguez',
#  'Patty Álvarez Padilla',
#  'Itala Ureta',
#  'Diana Pau González.',
#  'Randy Gage',
#  'Lulu Frompr',
#  'Luisa Rios',
#  'Dr. Moño.',
#  'Emily Chavez Daumas',
#  'Ricardo Calderón De La Barca',
#  'Ana Michell',
#  'Sergio Nava',
#  'Enrique Moreno',
#  'Esmeralda Salas.',
#  'Verónica Del Castillo',
#  'Margarita Miranda Correa',
#  'Luiggi Lavin',
#  'Milly Moreno',
#  'Yuri Mendoza',
#  'Alberto',
#  'Flor',
#  'Lavín11:11',
#  'Jhony',
#  'Jorge Rosas',
#  'Serratos',
#  'Andie Lozano',
#  'Gaby Jaime',
#  'David De Alba',
#  'Elizabeth Casillas',
#  'Israel Flores',
#  'Rodrigo Del Val',
#  'Jessica Garza',
#  'Ceciia Galindo',
#  'Lorena Arelluk',
#  'Karla Zorola',
#  'Estrella',
#  'Alejandro Saracho',
#  'Isabella Cisneros',
#  'Juan',
#  'Rebe',
#  'Lili Jaime',
#  'Patty Verdugo',
#  'Ana Lugo',
#  'Ana Munguía',
#  'Leonor Verdugo',
#  'Minerva Martinez',
#  'Cristian Chablé',
#  'Marcela Chavez',
#  'Leticia Rodriguez',
#  'Anna Ferro',
#  'Pilar Rosas',
#  'Patricia Moreno',
#  'Omar Perez',
#  'Yhashua Sámano',
#  'Jacky Moguel',
#  'Yoel',
#  'Raciel',
#  'Rosmy Quiroz',
#  'Oscar Lomeli',
#  'Oscar Lopez',
#  'Rodrigo Hellfer',
#  'Tato',
#  'Marisol',
#  'Caro Cruz',
#  'José Manuel De León Gutierrez']

# %%
authors_final = []

for author in authors_capped:
    split = author.split(' ')
    author_split = {
        "first_name": "",
        "last_name": ""
    }
    if len(split) == 1:
        author_split["first_name"] = split[0]
        authors_final.append(author_split)
    if len(split) == 2:
        author_split['first_name'] = split[0]
        author_split['last_name'] = split[1]
        authors_final.append(author_split)
    if len(split) == 3:
        author_split['first_name'] = " ".join([split[0], split[1]])
        author_split['last_name'] = split[2]
        authors_final.append(author_split)
    if len(split) > 3:
        author_split['first_name'] = " ".join([split[0], split[1]])
        author_split['last_name'] = " ".join(x for x in split[2:])
        authors_final.append(author_split)

authors_final
# Out:
# [{'first_name': 'Juan Carlos', 'last_name': 'Barrios'},
#  {'first_name': 'Jorge', 'last_name': 'Serratos'},
#  {'first_name': 'Alex Gomez', 'last_name': 'Medina'},
#  {'first_name': 'Rebeca', 'last_name': 'González'},
#  {'first_name': 'Spencer', 'last_name': 'Hoffmann'},
#  {'first_name': 'Alex', 'last_name': 'Palombo'},
#  {'first_name': 'Yoel', 'last_name': 'Sardiñas'},
#  {'first_name': 'Erika', 'last_name': 'Torres'},
#  {'first_name': 'Elisa', 'last_name': 'Ramírez'},
#  {'first_name': 'Alex', 'last_name': 'Vazquez'},
#  {'first_name': 'Adriana', 'last_name': 'Vega'},
#  {'first_name': 'Jenny', 'last_name': 'Linares'},
#  {'first_name': 'Elizabeth', 'last_name': 'Reséndiz'},
#  {'first_name': 'Rocío Jimenez', 'last_name': 'Nolasco'},
#  {'first_name': 'Diana Martínez', 'last_name': 'Partida'},
#  {'first_name': 'Francisco', 'last_name': 'Escobar'},
#  {'first_name': 'Mónica Viviana', 'last_name': 'Arias Arcila'},
#  {'first_name': 'Daisy', 'last_name': 'Rosales'},
#  {'first_name': 'Nara', 'last_name': 'Trejo'},
#  {'first_name': 'Sofía', 'last_name': 'Muñiz'},
#  {'first_name': 'Irma', 'last_name': 'Rocha'},
#  {'first_name': 'Nancy', 'last_name': 'Valiente'},
#  {'first_name': 'David', 'last_name': 'Hernández'},
#  {'first_name': 'Ana Paola', 'last_name': 'Ramos Uriarte'},
#  {'first_name': 'Jaime Guzmán', 'last_name': 'Fontanot'},
#  {'first_name': 'Jeanette', 'last_name': 'Candiani'},
#  {'first_name': 'Graciela', 'last_name': 'Pedro'},
#  {'first_name': 'Oscar', 'last_name': 'Ramírez'},
#  {'first_name': 'Chef Coco', 'last_name': 'González'},
#  {'first_name': 'Pasta Dura', 'last_name': 'Coco'},
#  {'first_name': 'Nicolás', 'last_name': 'Robles'},
#  {'first_name': 'Jesús', 'last_name': 'Rivas'},
#  {'first_name': 'Carolina', 'last_name': 'Candedo'},
#  {'first_name': 'José Fernando', 'last_name': 'Montes Arias'},
#  {'first_name': 'Jesus Alberto', 'last_name': 'Santacruz'},
#  {'first_name': 'Juan Manuel', 'last_name': 'Morales'},
#  {'first_name': 'José', 'last_name': 'Ardón'},
#  {'first_name': 'Angélica', 'last_name': 'Lighten'},
#  {'first_name': 'Shariteé', 'last_name': 'Salgado'},
#  {'first_name': 'Was', 'last_name': 'Editorial'},
#  {'first_name': 'Marina', 'last_name': 'Rodríguez'},
#  {'first_name': 'Mark', 'last_name': 'Achar'},
#  {'first_name': 'Doris', 'last_name': 'Michan'},
#  {'first_name': 'Josue', 'last_name': 'Mejia'},
#  {'first_name': 'Gumaro', 'last_name': 'Bracho'},
#  {'first_name': 'Patty', 'last_name': 'González'},
#  {'first_name': 'Lisayly Hurtado', 'last_name': 'Romero'},
#  {'first_name': 'Paco', 'last_name': 'Hernández'},
#  {'first_name': 'Olas De', 'last_name': 'Luz'},
#  {'first_name': 'Compilación De', 'last_name': 'Cuentos'},
#  {'first_name': 'Denisse', 'last_name': 'Rendón'},
#  {'first_name': 'Sandra', 'last_name': 'Ballesteros'},
#  {'first_name': 'Esther', 'last_name': 'Delgado'},
#  {'first_name': 'Sergio León', 'last_name': 'Hernández'},
#  {'first_name': 'Javier', 'last_name': ''},
#  {'first_name': 'Sahid', 'last_name': 'Reyes'},
#  {'first_name': 'Mihail', 'last_name': 'Millet'},
#  {'first_name': 'Jaime', 'last_name': 'Lokier'},
#  {'first_name': 'Arturo', 'last_name': 'Jiménez'},
#  {'first_name': 'Verónika', 'last_name': 'Santos'},
#  {'first_name': 'María', 'last_name': 'Felix'},
#  {'first_name': 'Sánchez', 'last_name': ''},
#  {'first_name': 'Luis', 'last_name': 'Rhino'},
#  {'first_name': 'Isabel', 'last_name': 'Vargas'},
#  {'first_name': 'César', 'last_name': 'Moysén.'},
#  {'first_name': 'Lucy', 'last_name': 'Santos'},
#  {'first_name': 'Luz', 'last_name': 'García'},
#  {'first_name': 'Lili', 'last_name': 'Alba'},
#  {'first_name': 'Paty', 'last_name': 'Anaya.'},
#  {'first_name': 'Verónika', 'last_name': 'Satos'},
#  {'first_name': 'José Luis', 'last_name': 'Monsalvo'},
#  {'first_name': 'Flor', 'last_name': 'Castillo'},
#  {'first_name': 'Bruno', 'last_name': 'Trinidad'},
#  {'first_name': 'Rosalba', 'last_name': 'Rodarte'},
#  {'first_name': 'Mirna', 'last_name': 'Guzmán.'},
#  {'first_name': 'Simon', 'last_name': 'Cohen'},
#  {'first_name': 'Coral', 'last_name': 'Mujaes'},
#  {'first_name': 'Nayo', 'last_name': 'Escobar'},
#  {'first_name': 'Raciel', 'last_name': 'Trejo'},
#  {'first_name': 'Lupita', 'last_name': 'Arias'},
#  {'first_name': 'Eduardo', 'last_name': 'Rodríguez'},
#  {'first_name': 'Patty Álvarez', 'last_name': 'Padilla'},
#  {'first_name': 'Itala', 'last_name': 'Ureta'},
#  {'first_name': 'Diana Pau', 'last_name': 'González.'},
#  {'first_name': 'Randy', 'last_name': 'Gage'},
#  {'first_name': 'Lulu', 'last_name': 'Frompr'},
#  {'first_name': 'Luisa', 'last_name': 'Rios'},
#  {'first_name': 'Dr.', 'last_name': 'Moño.'},
#  {'first_name': 'Emily Chavez', 'last_name': 'Daumas'},
#  {'first_name': 'Ricardo Calderón', 'last_name': 'De La Barca'},
#  {'first_name': 'Ana', 'last_name': 'Michell'},
#  {'first_name': 'Sergio', 'last_name': 'Nava'},
#  {'first_name': 'Enrique', 'last_name': 'Moreno'},
#  {'first_name': 'Esmeralda', 'last_name': 'Salas.'},
#  {'first_name': 'Verónica Del', 'last_name': 'Castillo'},
#  {'first_name': 'Margarita Miranda', 'last_name': 'Correa'},
#  {'first_name': 'Luiggi', 'last_name': 'Lavin'},
#  {'first_name': 'Milly', 'last_name': 'Moreno'},
#  {'first_name': 'Yuri', 'last_name': 'Mendoza'},
#  {'first_name': 'Alberto', 'last_name': ''},
#  {'first_name': 'Flor', 'last_name': ''},
#  {'first_name': 'Lavín11:11', 'last_name': ''},
#  {'first_name': 'Jhony', 'last_name': ''},
#  {'first_name': 'Jorge', 'last_name': 'Rosas'},
#  {'first_name': 'Serratos', 'last_name': ''},
#  {'first_name': 'Andie', 'last_name': 'Lozano'},
#  {'first_name': 'Gaby', 'last_name': 'Jaime'},
#  {'first_name': 'David De', 'last_name': 'Alba'},
#  {'first_name': 'Elizabeth', 'last_name': 'Casillas'},
#  {'first_name': 'Israel', 'last_name': 'Flores'},
#  {'first_name': 'Rodrigo Del', 'last_name': 'Val'},
#  {'first_name': 'Jessica', 'last_name': 'Garza'},
#  {'first_name': 'Ceciia', 'last_name': 'Galindo'},
#  {'first_name': 'Lorena', 'last_name': 'Arelluk'},
#  {'first_name': 'Karla', 'last_name': 'Zorola'},
#  {'first_name': 'Estrella', 'last_name': ''},
#  {'first_name': 'Alejandro', 'last_name': 'Saracho'},
#  {'first_name': 'Isabella', 'last_name': 'Cisneros'},
#  {'first_name': 'Juan', 'last_name': ''},
#  {'first_name': 'Rebe', 'last_name': ''},
#  {'first_name': 'Lili', 'last_name': 'Jaime'},
#  {'first_name': 'Patty', 'last_name': 'Verdugo'},
#  {'first_name': 'Ana', 'last_name': 'Lugo'},
#  {'first_name': 'Ana', 'last_name': 'Munguía'},
#  {'first_name': 'Leonor', 'last_name': 'Verdugo'},
#  {'first_name': 'Minerva', 'last_name': 'Martinez'},
#  {'first_name': 'Cristian', 'last_name': 'Chablé'},
#  {'first_name': 'Marcela', 'last_name': 'Chavez'},
#  {'first_name': 'Leticia', 'last_name': 'Rodriguez'},
#  {'first_name': 'Anna', 'last_name': 'Ferro'},
#  {'first_name': 'Pilar', 'last_name': 'Rosas'},
#  {'first_name': 'Patricia', 'last_name': 'Moreno'},
#  {'first_name': 'Omar', 'last_name': 'Perez'},
#  {'first_name': 'Yhashua', 'last_name': 'Sámano'},
#  {'first_name': 'Jacky', 'last_name': 'Moguel'},
#  {'first_name': 'Yoel', 'last_name': ''},
#  {'first_name': 'Raciel', 'last_name': ''},
#  {'first_name': 'Rosmy', 'last_name': 'Quiroz'},
#  {'first_name': 'Oscar', 'last_name': 'Lomeli'},
#  {'first_name': 'Oscar', 'last_name': 'Lopez'},
#  {'first_name': 'Rodrigo', 'last_name': 'Hellfer'},
#  {'first_name': 'Tato', 'last_name': ''},
#  {'first_name': 'Marisol', 'last_name': ''},
#  {'first_name': 'Caro', 'last_name': 'Cruz'},
#  {'first_name': 'José Manuel', 'last_name': 'De León Gutierrez'}]

# %%
with open("authors.json", "w") as json_file:
    json.dump(authors_final, json_file, indent=2)
